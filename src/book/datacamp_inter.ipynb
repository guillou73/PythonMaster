# %%
#list example
myFruitlist = ["banana","mango","pineapple"]
print(myFruitlist)
myFruitlist.append("Rasburry")
print(myFruitlist)
# Out:
# ['banana', 'mango', 'pineapple']
# ['banana', 'mango', 'pineapple', 'Rasburry']

# %%
#let's check tuple
myFruitTupple = ("Banana","Mango","Pineapple")
print(myFruitTupple)
print(f"Count -> {myFruitTupple.count("Banana")}")
print(len(myFruitTupple))
myFruitTupple.append("Rasburry")
print(myFruitTupple)
# Out:
# ('Banana', 'Mango', 'Pineapple')
# Count -> 1
# 3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 6
#       4 print(f"Count -> {myFruitTupple.count("Banana")}")
#       5 print(len(myFruitTupple))
# ----> 6 myFruitTupple.append("Rasburry")
#       7 print(myFruitTupple)
#
# AttributeError: 'tuple' object has no attribute 'append'
